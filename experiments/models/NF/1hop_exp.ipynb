# %%
import warnings
import pickle
import matplotlib.pyplot as plt
import numpy as np
import sys

sys.path.insert(0, '../../..')

from cde.density_estimator import NormalizingFlowEstimator
from cde.data_collector import MatlabDataset
from cde.density_estimator import plot_conditional_hist, measure_percentile
# Out:
# WARNING:tensorflow:From /Users/ssmos/.pyenv/versions/venv/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.

# %%
# matds = MatlabDataset('simple_queue_sr1_1M.mat') 
matds = MatlabDataset('../../data/simple_queue_sr0p5-4_1M.mat')
# Out:
#  Dataset loaded from .mat file. Rows: 7877152   Columns: 3

# %%
""" Take samples and fit density model """
# best: batchsize=300000, n_training_epochs=1500, n_flows=5

data = matds.get_data(100000)
Y = data[:,0]
X = data[:,1:]

""" fit density model """
model = NormalizingFlowEstimator("NF_1hop_exp", ndim_x=2, ndim_y=1,n_training_epochs=1000,n_flows=5,hidden_sizes=(16, 16),data_normalization=True)
model.fit(X, Y)
# Out:
# Step    0: train log-loss  712743.8750
# Step  100: train log-loss  323904.9375
# Step  200: train log-loss  275996.0625
# Step  300: train log-loss  263763.0312
# Step  400: train log-loss  256974.9062
# Step  500: train log-loss  251372.1562
# Step  600: train log-loss  246619.1562
# Step  700: train log-loss  243058.4375
# Step  800: train log-loss  240836.2812
# Step  900: train log-loss  239382.2969
# Step 1000: train log-loss  238338.0000

# %%
""" Save the trained model into file """

with open('saves/1hop_exp.pkl', 'wb') as output:
    pickle.dump(model, output, pickle.HIGHEST_PROTOCOL)

# %%
""" Load the trained model from file """

dummy = NormalizingFlowEstimator("NF_1hop_exp", ndim_x=2, ndim_y=1)
dummy.starttfsession()

with open('saves/1hop_exp.pkl', 'rb') as input:
    dummy = pickle.load(input)

model = dummy
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-6-c8f3e241843e> in <module>
#       1 """ Load the trained model from file """
#       2
# ----> 3 dummy = NormalizingFlowEstimator("NF_1hop_exp", ndim_x=2, ndim_y=1)
#       4 dummy.starttfsession()
#       5
#
# ~/Desktop/Research Project/Density Estimation/CDE_virtualenv/Conditional_Density_Estimation/cde/density_estimator/NF.py in __init__(self, name, ndim_x, ndim_y, flows_type, n_flows, hidden_sizes, hidden_nonlinearity, n_training_epochs, x_noise_std, y_noise_std, adaptive_noise_fn, weight_decay, weight_normalization, data_normalization, dropout, l2_reg, l1_reg, random_seed)
#      41                  random_seed=None):
#      42         Serializable.quick_init(self, locals())
# ---> 43         self._check_uniqueness_of_scope(name)
#      44
#      45
#
# ~/Desktop/Research Project/Density Estimation/CDE_virtualenv/Conditional_Density_Estimation/cde/density_estimator/BaseNNEstimator.py in _check_uniqueness_of_scope(name)
#     299         current_scope = tf.get_variable_scope().name
#     300         scopes = set([variable.name.split('/')[0] for variable in tf.global_variables(scope=current_scope)])
# --> 301         assert name not in scopes, "%s is already in use for a tensorflow scope - please choose another estimator name"%name
#     302
#
# AssertionError: NF_1hop_exp is already in use for a tensorflow scope - please choose another estimator name

# %%
plt.ioff()

""" plot the fitted distribution """
x_cond_plot = np.array([[40, 0.5],[40,1], [40,1.5] , [40,2]])
y_lim = (0, 150)
fig = model.plot2d(x_cond_plot, ylim=y_lim, resolution=300, show=False, prefix='predicted',fsize=[6,4],fdpi=100,fxlabel="y = end-to-end delay [time]",fylabel="p(y|x) [probability]")

""" plot the conditional histogram """
data = matds.get_data(matds.n_records)
fig = plot_conditional_hist(data,x_cond_plot, ylim=y_lim, resolution=150, show=True, holdonfig=fig, prefix='measured',fsize=[6,4],fdpi=100)

plt.show()

# %%
plt.ioff()

""" plot the fitted distribution """
x_cond_plot = np.array([[40, 1],[30,1], [20,1] , [10,1]])
y_lim = (0, 80)
fig = model.plot2d(x_cond_plot, ylim=y_lim, resolution=300, show=False, prefix='predicted',fsize=[6,4],fdpi=100,fxlabel="y = end-to-end delay [time]",fylabel="p(y|x) [probability]")

""" plot the conditional histogram """
data = matds.get_data(matds.n_records)
fig = plot_conditional_hist(data,x_cond_plot, ylim=y_lim, resolution=150, show=True, holdonfig=fig, prefix='measured',fsize=[6,4],fdpi=100)

plt.show()

# %%
''' Calculate Normalized Mean Absolute Error (NMAE) '''


dataset = matds.get_data(matds.n_records)
#dataset = matds.get_data(int(matds.n_records*0.1))
testdataset = matds.get_data(5)
testdataset = testdataset[:,1:]
perc_arr = np.array([ 70,80,90,99.9,99.99 ])
NMAEs = []

for j in range(len(perc_arr)):
    p_perc = perc_arr[j]
    res = []
    for i in range(len(testdataset)):
        prog = (j*len(testdataset)+i)/(len(testdataset)*len(perc_arr))*100
        print('\rCalculating percentiles [%d%%]'%prog, end="")
        xc = np.array([testdataset[i,:]])
        measured_perc,num_samples,avg = measure_percentile(dataset=dataset,x_cond=xc,p_perc=p_perc)
        if num_samples > 1000:
            #predicted_perc = model.new_quantile_cdf_m(x_cond=xc,alpha=p_perc/100, eps=1e-3, init_bound=200)
            predicted_perc = model.find_perc(x_cond=xc,alpha=(100-p_perc)/100, eps=1e-3, init_bound=200)
            res.append(abs(measured_perc-predicted_perc)/measured_perc)
        else:
            continue

    nmae = np.mean(res)
    #print("percentile: ", p_perc ,", number of samples: ", len(res), " MAE:", nmae)
    NMAEs.append(nmae)

fig, ax = plt.subplots()
ax.plot(range(len(NMAEs)),NMAEs, marker='*') #substitute actual plotting here
ax.set_xticks(range(len(NMAEs)))
ax.set_xticklabels(perc_arr)
plt.xlabel('percentile')
plt.ylabel('NMAEs')

plt.show()
# Out:
# Calculating percentiles [96%]
